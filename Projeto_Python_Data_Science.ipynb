# %% [markdown]
# <a href="https://colab.research.google.com/github/Ana-Diniz/Ana-Diniz/blob/main/Projeto_Python_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python para Data Science
#
# Notebook para o curso de Python para Data Science publicado na plataforma da [Alura](https://www.alura.com.br/)

# %% [markdown]
# # Introdução ao Python
#
# Vamos conhecer o Python, nosso ambiente de estudo e também faremos nosso primeiro código nessa linguagem!

# %% [markdown]
# ## Google Colaboratory
#
# Já aprendemos o que é o [Python](https://www.python.org/) agora vamos aprender a utilzar o [Google Colaboratory](https://colab.research.google.com/) e programar em um notebook.
#
# Vamos testar algumas funções dessa ferramenta.

# %% [markdown]
#  **`>>> Use essa célula para mover <<<`**

# %%
# Out:
# 10

# %% [markdown]
# ## Olá mundo!
#
# Vamos conhecer mais como funciona o ambiente interativo de um notebook. Para isso vamos executar nosso primeiro comando em Python: [`print()`](https://docs.python.org/3/library/functions.html#print)

# %%
print('olá, mundo!')
# Out:
# olá, mundo!

# %%
print (10)
# Out:
# 10

# %%
print ('Namaria')
# Out:
# Namaria

# %% [markdown]
# # Manipulando dados
#
# Vamos aprender sobre as variáveis no python, como elas são declaradas e utilizadas além de conhecer outros comandos dentro do Python. :D

# %% [markdown]
# ## Variáveis
#
# Em Data Science nós trabalhamos com vários dados e informações, então é essencial saber trabalhar com variáveis.

# %% [markdown]
# Criamos uma variável no python através da atribuição de um valor a ela.
#
# Para fazer isso, colocamos o nome da variável um sinal de igual (`=`) e o valor que queremos atribuir

# %%
idade = 5

# %%
print (idade)
# Out:
# 5

# %%
idade = 10
print (idade)
# Out:
# 10

# %%
idade = 15
idade
# Out:
# 15

# %% [markdown]
# Nomes que **não** podemos definir para variáveis:
#
# - **Nomes que começam com números**
#   - Exemplos: `10_notas`, `2_nomes_casa`, etc.
# - **Palavras separada por espaço**
#   - Exemplos: `Nome escola`, `notas estudantes`, etc.
# - **Nomes de funções do Python**
#   - Exemplos: `print`, `type`, etc.

# %% [markdown]
# > Letras maiúsculas e minúsculas vão gerar diferentes variáveis. A varíavel `idade` é diferente de `Idade` que por sua vez também é diferente de `IDADE`:
# ``` Python
# idade = 1
# Idade = 2
# IDADE = 3
# _idade = 4
# _idade_ = 5
# print(idade, Idade, IDADE, _idade, _idade_)
# 1 2 3 4 5
# ```

# %% [markdown]
# ## Tipos de variáveis
#
# Cada variável contém uma classe especifica quanto ao tipo de objeto que ela está se referenciando. Essas classes vão ser diferentes a partir do tipo de dado que nós atribuimos a uma variável.
#
# Para saber a classe de cada elemento usamos a função [`type()`](https://docs.python.org/3/library/functions.html#type)

# %%
i = 5
type (i)
# Out:
# int

# %%
f = 9.8
type(f)
# Out:
# float

# %%
s = 'Ana'
type (s)
# Out:
# str

# %%
b = True
type (b)
# Out:
# bool

# %% [markdown]
# Em um conjunto de dados escolares podemos ter vários tipos de informações. Digamos que tenhamos acesso à ficha de dados do aluno *Frabicio Daniel* como transformamos ela em variáveis no Python?
#
# #### Ficha:
#
# - Nome: Fabricio Daniel
# - Idade: 15 anos
# - Media do semestre: 8,45
# - Situação de aprovação: Verdadeira (aprovado)

# %%
nome_aluno = 'Fabricio Daniel'
Idade_aluno = 15
Media_aluno = 8.45
Aprovado = True

# %% [markdown]
# ## Variáveis numéricas
#
# Entre os tipos de dados numéricos vamos nos focar no tipo `inteiro` e `float`.

# %% [markdown]
# Temos uma tabela de informação de empregos quanto ao cargo, quantidade de pessoas empregadas e o salário correspondente:
#
# |Cargo | Quantidade | Salário|
# |---|---|---|
# |Segurança | 5 | 3000 |
# |Docente | 16| 6000|
# |Diretoria| 1 |12500|
#
# Precisamos trabalhar com esses dados fornecendo:
#
# - A quantidade total de empregados;
# - A diferença entre o salário mais baixo e mais alto; e
# - A média ponderada da faixa salarial da escola.

# %%
q_seguranca = 5
s_seguranca = 3000

q_docente = 16
s_docente = 6000

q_diretoria = 1
s_diretoria = 12500

# %%
total_empregados = q_seguranca + q_docente + q_diretoria
total_empregados
# Out:
# 22

# %%
diferenca = s_docente - s_seguranca
diferenca
# Out:
# 3000

# %%
media = (s_seguranca*q_seguranca + s_docente*q_docente + s_diretoria + q_diretoria)/(total_empregados)
media
# Out:
# 5613.681818181818

# %% [markdown]
# ## Strings

# %% [markdown]
# Strings são caracterizada por ter um conjunto de caracteres formando um texto.
#
# Strigs podem ser criadas ao atribuirmos a uma variável um dado que esteja entre aspas simples (`'`) ou aspas duplas (`"`)

# %%
s1 = 'Ana'
s2 = 'Ana'
print (s1)
# Out:
# Ana

# %% [markdown]
# As variáveis textuais contém vários métodos que nos ajudam a formatar strings. Métódos podem ser executados ao definirmos um objeto seguindo a seguinte estrutura:
#
# ```
# objeto.metodo()
# ```
#
# Existem métodos que não necessitam dos `()`, é preciso verificar a documentação de cada caso.

# %% [markdown]
# ---
# **Situação:**
#
# Recebemos uma variável com o nome de uma professora da escola para inserimos no cadastro. No entanto, precisamos tratar esse texto antes de inserirmos no sistema

# %%
texto = '  Geovana Alessandra dias Sanyos '

# %% [markdown]
# O objetivo final é que o nome esteja da seguinte forma:
#
# ```
# 'GEOVANA ALESSANDRA DIAS SANTOS'
# ```

# %% [markdown]
# ### [`str.upper()` ](https://docs.python.org/3/library/stdtypes.html#str.upper)
# Converte uma string para maiúsculas

# %%
texto.upper()
# Out:
# '  GEOVANA ALESSANDRA DIAS SANYOS '

# %% [markdown]
# ### [`str.lower()`](https://docs.python.org/3/library/stdtypes.html#str.lower)
# Método converte uma string para minúsculas.

# %% [markdown]
# ### [`str.strip()`](https://docs.python.org/3/library/stdtypes.html#str.strip)
# Método remove os espaços em branco do início e do fim de uma string.

# %%
texto.strip()
# Out:
# 'Geovana Alessandra dias Sanyos'

# %% [markdown]
# ### [`str.replace(antigo, novo)`](https://docs.python.org/3/library/stdtypes.html#str.replace)
#
# Método substitui todas as ocorrências do texto "antigo" na string por "novo"

# %%
texto.replace('y','t')
# Out:
# '  Geovana Alessandra dias Santos '

# %% [markdown]
# ### Observações
#
# 1. Os métodos retornam uma **tranformação**, não a executam no texto!
#
# 2. Além disso, podemos acumular a execução de métodos.

# %%
texto = '  Geovana Alessandra dias Santos '
texto = texto.strip().replace('y','t').upper()
texto
# Out:
# 'GEOVANA ALESSANDRA DIAS SANTOS'

# %% [markdown]
# Para que seja executada a transformação nós podemos atribuir às saídas das transformações à variável

# %% [markdown]
# ## Coletando dados
#
# Em algumas aplicações precisamos coletar valores da pessoa usuária do nosso projeto. Em python conseguimos coletar dados de usuário através do comando [`input()`](https://docs.python.org/3/library/functions.html#input).
#
# Para fazer essa coleta podemos atribuir essa função à uma variável.

# %% [markdown]
# O retorno desse comando sempre será uma *string*. Isso quer dizer que mesmo que façamos uma coleta de algo que deva ser numérico, ele será uma string.
#
# Então, será preciso **converter o resultado caso não seja desejável obter uma string**.

# %% [markdown]
# Existem funções para conversão de valores:
#
# - Inteiros: [`int(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#int)
# - Float: [`float(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#float)
# - String: [`str(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#func-str)
# - Booleano: [`bool(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#bool)

# %%
ano_entrada = input('Escreva o ano de ingresso do(a) estudante: ')
# Out:
# Escreva o ano de ingresso do(a) estudante: 2023

# %%
type(ano_entrada)
# Out:
# str

# %%
ano_entrada = int (input('Escreva o ano de ingresso do(a) estudante: '))
# Out:
# Escreva o ano de ingresso do(a) estudante: 2023

# %%
type(ano_entrada)
# Out:
# int

# %% [markdown]
# Buscaremos apresentar melhor agora o resultado que obtivemos da transformação. Nós conseguimos formatar e apresentar o nosso resultado misturando strings com valores não textuais.
#
# Para fazer isso usamos a estrutura de formatação `f` com strings.

# %% [markdown]
# ###***Coleta e amostragem de dados***
#
# *.proj*

# %%
nota_entrada = float(input('Digite a nota do teste de ingresso: '))
# Out:
# Digite a nota do teste de ingresso: 2022

# %%
nome = str(input('Olá, informe o seu nome: '))
idade = int(input('Informe sua idade: '))
altura = float(input('Informe sua altura em centímetros'))
altura = altura/100
print (('você se chama: {}, tem:  {} anos e tem {:.2f} metros de altura!').format(nome, idade, altura))
# Out:
# Olá, informe o seu nome: Ana
# Informe sua idade: 20
# Informe sua altura em centímetros163
# você se chama: Ana , tem:  20 anos e tem 1.63 metros de altura!

# %%
print('Calculadora com operadores')
# Out:
# Calculadora com operadores

# %% [markdown]
# ### ***Calculadora com operadores***
#
# *.proj* __*apenas exercitando o básico...*

# %% [markdown]
# * Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a soma dos dois valores.
# * Crie um programa que solicite três valores numéricos à pessoa usuária e imprima a soma dos três valores.
# * Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a subtração do primeiro pelo o segundo valor.
# * Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a multiplicação dos dois valores.
# * Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e realize a divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.
# * Crie um programa que solicite dois valores numéricos, um operador e uma potência, e realize a exponenciação entre esses dois valores.
# * Crie um programa que solicite dois valores numéricos, um numerador e um denominador e realize a divisão inteira entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.
# * Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e retorne o resto da divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.
# * Crie um código que solicita 3 notas de um estudante e imprima a média das notas.
# * Crie um código que calcule e imprima a média ponderada dos números 5, 12, 20 e 15 com pesos respectivamente iguais a 1, 2, 3 e 4.

# %%
#Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a soma dos dois valores.
print('Informe dois numeros inteiros que serão somados: ')
a = int(input(''))
b = int(input(''))
print('a soma é: ', a+b)
# Out:
# Informe dois numeros inteiros que serão somados:
# 5
# 4
# a soma é:  9

# %%
#Crie um programa que solicite três valores numéricos à pessoa usuária e imprima a soma dos três valores.
print('Please enter three integer numbers to be added together: ')
a= int(input(''))
b= int(input(''))
c= int(input(''))
print('The sum is: ', a+b+c)
# Out:
# Please enter three integer numbers to be added together:
# 3
# 6
# 9
# The sum is:  18

# %%
#Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a subtração do primeiro pelo o segundo valor.
print('Enter two integer numbers to be subtracted: ')
a = int(input(''))
b = int(input(''))
print('the sub. is: ', a-b)
# Out:
# Enter two integer numbers to be subtracted:
# 1202
# 1456
# the sub. is:  -254

# %%
#Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e retorne o resto da divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.
print('enter a two numbers to be divided: ')
a = int(input(''))
b = int(input(''))
if b == 0:
  print('The denominator cannot be equal to zero')
  b = int(input(''))
print('The rest of this division is: ', a/b)
# Out:
# enter a two numbers to be divided:
# 4
# 0
# The denominator cannot be equal to zero
# 2
# The rest of this division is:  2.0

# %%
#Crie um código que solicita 3 notas de um estudante e imprima a média das notas.
print('Please, provide three students grades to generate the arithmetic mean: ')
first_grade = float (input(''))
second_grade = float (input(''))
third_grade = float (input(''))
ar_grade = first_grade + second_grade + third_grade
ar_grade = ar_grade/3
print('The arithmetic mean is: {:.2f}'.format(ar_grade))
# Out:
# Please, provide three students grades to generate the arithmetic mean:
# 6
# 9
# 5
# The arithmetic mean is: 6.67

# %%
#Crie um código que calcule e imprima a média ponderada dos números 5, 12, 20 e 15 com pesos respectivamente iguais a 1, 2, 3 e 4.
'''a = 5
b = 12
c = 20
d = 15
w1 = 1
w2 = 2
w3 = 3
w4 = 4

weig_mean = (a*w1 + b*w2 + c*w3 + d*w4)/(w1+w2+w3+w4)
print('The weighted mean is: {:.2f}'.format(weig_mean))
'''
#this is just a version that interacts w the user, for fun
print('Please, provide four numbers to generate the weighted mean. Then, provide four numbers to be the weights: ')
a = float (input(''))
b = float (input(''))
c = float (input(''))
d = float (input(''))
w1 = float (input(''))
w2 = float (input(''))
w3 = float (input(''))
w4 = float (input(''))

weig_mean = (a*w1 + b*w2 + c*w3 + d*w4)/(w1+w2+w3+w4)
print('The weighted mean is: {:.2f}'.format(weig_mean))
